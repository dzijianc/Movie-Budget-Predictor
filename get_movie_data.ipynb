# %%
import requests
from bs4 import BeautifulSoup
import json
import cv2
import random
import csv

# %%
def get_genre_n_pages(genre, n=1): #default is ==1 which means 50 entries
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1", "Accept-Language": "en-US, en;q=0.5"}
    start = 'https://www.imdb.com/search/title/?title_type=feature&genres='
    mid = '&count='
    num = str(n*50)
    genre_url = start + genre + mid + num
    print(genre_url)
    response = requests.get(genre_url, headers=headers)

    if not response.ok:
        print('Status Code:', response.status_code)
        raise Exception('Failed to get web page' + genre_url)

    doc = BeautifulSoup(response.text)

    return doc

def fetch_movie_page(imdb_url):
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36"
    }
    response = requests.get(imdb_url, headers=headers)
    if response.ok:
        return BeautifulSoup(response.text, 'html.parser')
    else:
        return None
    
def get_genre(parsed_html):
    if parsed_html:
        genre_section = parsed_html.find('div', {'data-testid': 'genres'})
        if genre_section:
            genre_tags = genre_section.find_all('a')
            genres = [genre.text.strip() for genre in genre_tags]
            return genres
        else:
            return "Genres not found"
    else:
        return "Invalid HTML content"
    
def get_budget(movie_soup):
    try:
        budget_div = movie_soup.find('li', {"data-testid": "title-boxoffice-budget"})
        budget = budget_div.text.split("$")[1].split(" ")[0]
        budget = budget.replace(",", "")
        return int(budget)
    except (AttributeError, ValueError):
        return None
    
def get_trailer_link(movie_soup):
    try:
        official_trailer = movie_soup.find('a', {'aria-label': 'TrailerOfficial Trailer'})
        if official_trailer is None:
            link = movie_soup.find('script', {'type': 'application/json'})
            json_ob = json.loads(link.string)
            url = json_ob['props']['pageProps']['aboveTheFoldData']['primaryVideos']['edges'][0]['node']['playbackURLs'][0]['url']
            return url

        headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36"}
        imdb_url = 'https://www.imdb.com' + official_trailer['href'].split('?')[0]
        response = requests.get(imdb_url, headers=headers)
        page = BeautifulSoup(response.text, 'html.parser')
        link = page.find('script', {'type': 'application/json'})
        json_ob = json.loads(link.string)
        videos = json_ob["props"]["pageProps"]["videoPlaybackData"]["video"]["playbackURLs"]
        url = videos[1]['url']
        # urllib.request.urlretrieve(url, 'test.mp4')
        return url
    except (IndexError, ValueError):
        return None

# %%
genres = ['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime',
          'Documentary', 'Drama', 'Family', 'Fantasy', 'Film-Noir', 'History', 'Horror',
          'Music', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Short',
          'Sport', 'Thriller', 'War', 'Western']

# Randomize selected genres
# selected_genres = random.sample([_ for _ in range(len(genres))], 10)
selected_genres = [10, 15, 12, 1, 19, 0, 3, 9, 6, 11]
def get_training_data():
    with open('test.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        fields = ['genres', 'budget', 'link']
        writer.writerow(fields)

        # Select movies from each genre
        for i in selected_genres:
            genre = genres[i]
            doc1 = get_genre_n_pages(genre=genre, n=1)
            movie_tags = doc1.find_all('li', class_ = 'ipc-metadata-list-summary-item')

            found_movie = False
            j = 0
            while (not found_movie):
                imdb_url = 'https://www.imdb.com'
                a_tag = movie_tags[j].find('a')
                href_full = a_tag['href']
                href_part = href_full.split('?')[0]
                sample_url = imdb_url + href_part
                page = fetch_movie_page(sample_url)
                movie_genres = get_genre(page)
                movie_budget = get_budget(page)
                movie_trailer = get_trailer_link(page)
                if movie_budget != None and movie_trailer != None:
                    found_movie = True
                    writer.writerow([movie_genres, movie_budget, movie_trailer])

                    # vidcap = cv2.VideoCapture(movie_trailer)
                    # success,image = vidcap.read()
                    # count = 0
                    # while success:
                    #     cv2.imwrite("test/movie%d_frame%d.jpg" % (i, count), image)     # save frame as JPEG file      
                    #     success,image = vidcap.read()
                    #     print('Read a new frame: ', success)
                    #     count += 1
                    #     success = False
                
                j += 1
                print(movie_genres, movie_budget, movie_trailer, '\n')
    file.close()

# %%
a = get_training_data()
# Out:
# https://www.imdb.com/search/title/?title_type=feature&genres=Film-Noir&count=50
# ['Crime', 'Drama', 'Film-Noir'] 400000 https://imdb-video.media-imdb.com/vi770359577/1434659607842-pgv4ql-1603754033591.mp4?Expires=1712786764&Signature=Bp6xAayO-iTKCcW0bqjWVjiq3aCyJtRbIAxguw3PWbxuFyAmPC2Feb1Y1j0a4kina7yAZVL-NH2hWtKtRv5DCii4pG99fw0uRkqWdWz56Q9wvMlGiMQnyknneBRA831Pw-6RuLLZqo~nuw70b2L8WwvoRcigd5ns6BNaiXZpV2Q0mTuJ9NgGvZMNaFQUJKQwOkY0V1A2-zxzSsJD~Bq6-pMRVz8nQd59CkQuIoUqvMvB5VtkHcd~fe8fMipxdKjQm66rWK4mYmF3tcr5wq~D6cXAIRzJx1bgOVgjxpohdTQInLU~v8qbrIxd-5K09ZFoKysWCkTAqHY0CRltyBPIww__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Mystery&count=50
# ['Action', 'Adventure', 'Crime'] None https://imdb-video.media-imdb.com/vi1229440793/1434659607842-pgv4ql-1707317532717.mp4?Expires=1712786766&Signature=rSP52JVKIqKYRpD4pfcLyhpWKBlsw~k3OZUKfUxCcFTcM3nV24YE6fGpaFxqIzRZSo-9jSDnUe6w2lP3SSrsAnSEcNRQ6LSYqoTN52Ee4aTNKt4fAUBcx43fTQQCH6S~wBY~Y-7lsfIJphlT0Eql3gWxlup7nctyOr3YECMbckE32fnAh-ZqyaWTSRgEfNW4TvAQViXGgjti7yIHODKzf-HW5b~3a4rwnXMpL8SmkXktkAbIBfzGLT3mscthlGm5CgMMPCpzYRMkGdWlE216YD4HAwymnI-U26WTvA8A00DRAJA5x5sXIMDAcH-hCKpHfMW33sK2vW15VC9fzaUMmQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Crime', 'Drama', 'Mystery'] 30000000 https://imdb-video.media-imdb.com/vi672579865/1434659529640-260ouz-1608655019804.mp4?Expires=1712785999&Signature=STIfLCdTdDKSzWxMrz7bjkWdsg8MSiriTOJoEU8KjOeJvgE4rTWYGqh3MOjBpTvXRXp0pwZz850yuNxKELh8vADIwyiEu5g6UrURHIvW0ckgRkGohH9gI1Wp5rscOo5iTj-QUE47fO-rUkjXEseZbQD-fGvSBrZjJaMSYi66rIlMg1nMNOJxMasupEJLwkAbe94h1jTJydAACaGXc~UC1FEWLyf1gawlLD6iZz38HcScpylRoF0Te-BVh~vpa-qEHph7M1EiY-rXBbbtNoFwKip020luZ2baazSL2vLELpdX4b6Nx5ZU2jTMhrrhB43CT03ZE9ar5Ax~v5eom4Zhtg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Horror&count=50
# ['Horror', 'Thriller'] None https://imdb-video.media-imdb.com/vi2355414809/1434659529640-260ouz-1704990107247.mp4?Expires=1712786013&Signature=H1WBWLw0GIYcgAMKTLQ4l5ZNGXoirJoUBI0pfAsnPio7RA8yru2geJ7kpDeLthDvyykeMgWPM0XjFezY-EL0YN-NEzB7ubjhVZfiWNkNlU9tYCI2RJaRqUgo5wqW02nvQJT3ZrDtQhUuYJkZV1trtFk-kRtLzHodM0D0n4VHG2yEQ6jQZnjMTj3Wtw8IHM00yhMraEOUFHguNLXztIuS07li1tG49M5Ia4XnqwYBI6VvBxoUrwM3N4eCQ-l-lAwFvr1verRpqF1bl38Hf8A2jk22jBu0M-r1hJ2PpVaTvl-Un3uOK5h~4eHLiBfW-dK3lDVB2JSmbWS6qTLO-fam2A__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Horror'] 30000000 https://imdb-video.media-imdb.com/vi934266393/1434659529640-260ouz-1710173661362.mp4?Expires=1712786002&Signature=AnGWFrDevZSKJJ3ITuXblVdk8lM~Et3mnSxdnmGmIxDbZXHogvyoEbkeENdnhZA65FBAYZvWXl6eJm~GedupI63Ow-1aoyDIammmC-SGKsiEuWlW-Oar6ynIdgxw6J2BScDTA8XhSEGMvNKighSFGW7Qkx5rT8keZ8ODPqLYeDDtuJWFJAX~BuMaH61TJ0pqAUNZtGSgrLEFYHEyy39-~88RdWtn1LRtbMcR1xGEs~kUCwZCq8otnsoV~C3GVtXAKBmG-nZ6HqQ1whoh3~RBPH78BpcDqCi4NS5ehl~bHOgIAuyfuf9tCAnzsayRPDZysFkQhpTxsaNAAQR7-IcnwA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Adventure&count=50
# ['Action', 'Adventure', 'Sci-Fi'] 135000000 https://imdb-video.media-imdb.com/vi397461017/1434659529640-260ouz-1707932046997.mp4?Expires=1712786775&Signature=h12bWAUsLjsQ7-p-2rHWYsz9vOSfiIipXQvIVthL2zi7HZTGlTL9E2Vn2ehpbriFyq0KN3t1qRL09MjODprPnh-FE3HBy~i7S-D1pxaeZVwB2ShciN6Pe526PbCtrL0F~-2g2xzQwnZrueUOwXGH5GQy2n9brXAqBe9c9~KHbmMxq3ZFkIcKkkOjiR6~PaMMQ29MMihWDYwWYXKhr9yZxstWddX-Oj0m3kNQW5~C8OeY7e3eMFF~MScf0-~xOHqugyxlHfbQY~-8xaggntVrFSumicgu0fd5Oy7mH-IrApgPPggsIK7QGezH~3ET43lnn7dKv1bUktqTnwyZEs1Erg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Sport&count=50
# ['Drama', 'Sport'] None https://imdb-video.media-imdb.com/vi27444761/1434659529640-260ouz-1709220828048.mp4?Expires=1712786778&Signature=XOYilAywXzACSlnnPal-~nwLWioLFeF6cnqsPqb18YhpkGvTwX7NCtea0GQDEZu4hVNv64WhQ~MoXI8Ci8YZJ-tLUA4dDFt6cSHSrlzyI-uqnvizN--~gKG-iIDbNEgzpnl4-DHo~7ybMJ3tvTXj1MsKKSX9v5A1USdc7FrUEvgEl8BmmLChAIrseM2uXvWNylCrVV1pBAnulm~08LDJBhF0vNTtbZnKOyBZvWXqO0NSO~B~2ZTxCmsHnmdIhcsqGeS~UYyPIMY-GRUmfozXv1ZEJvQioS0ZEBU2WwkibFBxubdUFfAN2FTgZK8kkk7l89pVK4JjuFK8AyC06wWoHQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Drama', 'Romance', 'Sport'] None https://imdb-video.media-imdb.com/vi2491663897/1434659529640-260ouz-1711548437338.mp4?Expires=1712786007&Signature=j7d1tbzkrzkA3ii8QOPZ-cLbSO~bqMN-5T7OVX5BpgsHOc5AUt1FJvrBsnyf5hy0T1P7nSfBwxYVFaMtr0ZGXPbUtXR-dLn26UlqbquD3kB1RiVXoUHlRjeescaaJ0p46-um-trUC2viovFkjtGWcssE8-DqvSxY6DYc5-zK3QZl1FyPo7aPd7lgXe8djwqMq9nWkNfJ1PrVW~OdGaXOlJiE3a2nkJem75S7o4oDK9~X4Ih-LLiaaGcbDHdK2EgJggjvMLuFetCT1w0ibK-cVBZZ5ee2DRSECDDqW8sjPhQExdpecB-Wl99jIWs4OWDLbMGg8L25cPdRBVF9~10edA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Biography', 'Drama', 'Sport'] 15000000 https://imdb-video.media-imdb.com/vi2915223321/1434659529640-260ouz-1697034123918.mp4?Expires=1712786781&Signature=Zpi6IphPVh~DJOHhjvqxF0meu6WmVYPpVpJG993weIgnckMW09hiyI~EbuRZMe7M6bc9BTylTSqGD19Ud0FroFrqewSiLcBr3XhOGpjKT~cCwX82h7Hx5jRx78SAlrwW2pRY-bllZper67Tn4JXegwRwzOEw44NVgb5wvPIPWJPJNJmhfJT9WkU1GC9MjfEXTYDuvHEZC6Qy12SenThfMq~m~tk2CMrWcoNpO40uTsdAp9u7r1GemqBZ-DFszuhHdY~gBNuYdQ2YIhMpPZ9RyrdrUMUMfmcdFH2oKJ0QLhuUQWeeBqV6YTKOmwqYmwD5RY8xrz0zB-K52aaxgpuX-g__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Action&count=50
# ['Action', 'Adventure', 'Sci-Fi'] 135000000 https://imdb-video.media-imdb.com/vi397461017/1434659529640-260ouz-1707932046997.mp4?Expires=1712786775&Signature=h12bWAUsLjsQ7-p-2rHWYsz9vOSfiIipXQvIVthL2zi7HZTGlTL9E2Vn2ehpbriFyq0KN3t1qRL09MjODprPnh-FE3HBy~i7S-D1pxaeZVwB2ShciN6Pe526PbCtrL0F~-2g2xzQwnZrueUOwXGH5GQy2n9brXAqBe9c9~KHbmMxq3ZFkIcKkkOjiR6~PaMMQ29MMihWDYwWYXKhr9yZxstWddX-Oj0m3kNQW5~C8OeY7e3eMFF~MScf0-~xOHqugyxlHfbQY~-8xaggntVrFSumicgu0fd5Oy7mH-IrApgPPggsIK7QGezH~3ET43lnn7dKv1bUktqTnwyZEs1Erg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Biography&count=50
# ['Biography', 'Drama', 'History'] 100000000 https://imdb-video.media-imdb.com/vi2053751833/1434659529640-260ouz-1683541736696.mp4?Expires=1712786787&Signature=I1ARiBCPcJpwjALuLSXVBvvC03NIQLGiCpqV-DfctpQ0ZuONcof96ExfssHBGfdFrd6ZSrw0fMzLq4saHqHJ~YnhQH82y0dY9uLViiIIDF09xbZdNSpZoitSzfBgfyo~BPPRNZV2-qLir3McoxkacafkEqlvnDYI786CcjiRoAGwFDMwtGkKcVzBy-BNC68Jx2pDgz39rnBgj5T1e2xAmS3qXSuzXrvbmBINCKhjtSqUt22Xc1yJx8Y8dS7z4GyXWdd8Mg18l-YjMqsXhpJwcN6GX~YlpetQB8Y6GFZrJ~p1EaP10JST6MzHTF43Rht3pmunlcB~jTKre0aJLAmKeA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Fantasy&count=50
# ['Adventure', 'Comedy', 'Fantasy'] 100000000 https://imdb-video.media-imdb.com/vi2606483225/1434659529640-260ouz-1706537435142.mp4?Expires=1712786790&Signature=uea73n4VOD1mPu0pLmapIW7S0Vxdn-Ueq2ZLqD0OUtuLxMwcTYDl7-2ry54ssUnhfkujyGK9IbNQr3gd2egkbMNvFDjhX5Sb4Pwot~B1JHA5LpgHqFOgx1BAvOCrP7hU8wJz7af0jQwuIdaZ9NWhuXuIHV5xBtM7U1kwWilK4esZjZUJZ0DUl3yCr5rkmsENBIVkAhpP91Iwzn3aoLNfw~HWwjtAUm0A5M7PcjF4Ri1V3W6ITL1ydaOUxhOGG37QIH1R~Sjn8qA-Wu3tVTLDrCn4Fb-KJbshtRVRY2hEXtJtBCb0kkdzZFcoqPcr5RcyY4zG8pne-hHGUPnf~zWhhA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Documentary&count=50
# ['Documentary'] None https://imdb-video.media-imdb.com/vi2292368921/1434659529640-260ouz-1709239105375.mp4?Expires=1712786793&Signature=QKoj63p0Jcf8gasCifItykubGfjgOAmEDl~BFrXAXBkUcMJAUmoLLJbcXJ0UNDnndSiAGvPnn8tHLPwgdMT41Rs5bbU4KhXhqlUVyJ4mIHNLhO77rHJqJOCL9IDbLOMc6Y137mL5iEeyXRtPvT57bpIdK-J7Ii-qR~rjGFA5WyIFXOlMo9htqO2AvdIOPen0M9c7UMJn7-xGrGt-ZTdopnMIFx7n7Nsr7oHicPo4iQqXJyesG3Plhfec~F0YY5Csn571MIKqo3S31ppSkfzKDNqb-mUZvuRzwAJv91V7CN6LUaSkMQ3Tf~nNs64Z~7CcVamoq3e8nJGKDSzVmVR8KQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Crime', 'Drama'] None None
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi3115501081/1434659529640-260ouz-1708096501057.mp4?Expires=1712786796&Signature=V608pC2r4af7fwW0Ird0mDgZi6Zq8zp3N2wBdPcQqoMQbERt-qYeyYEJkHeUrOrgbvb4Mg~c-7-8pE4NRW8Pg-G3VHJxTEeeYRdF0kA5G6c99BSwJhoiVCD7LyhtbKDVJ~1t5KKWs61-Djpz~IaoyeIcSOm6o9~AA6z~lojKcncVOjXOKc0ykSrd6vEbf3quiSAYyuB6Mc-aV-0gVjy9r3PNdMr~zt0OUHSQU0XhIUFrlznwBaE48caWMJ7pUlsMJ~fhqZCK1eGl38pEpZVzCTc1i891uDdW6th9dlkgPNuo7rlBdbX5p~1yRpoEpaxjmp7kbfsPaCttKIR59xyWmQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Crime'] None https://imdb-video.media-imdb.com/vi3717383705/1434659529640-260ouz-1710341817819.mp4?Expires=1712786798&Signature=TV2iNf2RBX8PN4ol63bk8gY7XGg5mDai9~ahdEvzk4qYyDEqx2UFqB7J70UNx~3rwnzM5~Hf-fuc7kBy9tMzNq25wix9yFcJ15igoGgaBtKCmCfPWZ4EJGYGTf3oUyP23UgGQ4hRwgXnfrHkVAtyL448EP0MfmvInUJnWJgyFj-P9cLE9j5ZZWG0fmBM~IWP814tRHw6tkHb6sN0kfuHNne8UAjyBzprE8Ok-ROM3sPBpdahybMAU5s~mq8eK236HdZuDMS2NXeR0K6tfVlA6l8NYWoWrp0GN-BtRNvdZJmUS0t8s5PKzxvuyb0t~yiGppTdDYkY7CHycRiIIJPeqg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'War'] None https://imdb-video.media-imdb.com/vi336774937/1434659529640-260ouz-1700736399325.mp4?Expires=1712786800&Signature=luPQIEceMWdJBvL4OzJqvT~6zHLABaSPNv6tjNMIbzKdGSPFunsuD4TdLoCWCIB6X6~kdXRBAix3Yo1zd1Bciiwm5Z7ZAlzb0URCcGcH3aYsKHEEhWnj2LWMZT4ABf7Ismgv4U0K0CV9wAuProZlbJcMwdpliUuNdF~oKceVihkqn14jqasAMsz~i0y2R3fLOd7TPp2Pv1r~LuTClCfsGuGD0uTUJc2O9gmR4Cz4eXhCA-Xc9yYfYk7ewCdmnmfokyS87uMQuhbtg6zxAd8yWG8qrOetH9jdzjn7sBs9J4lt7YPCufhLOxFqFb7H5Y7S9~ZOmTkclR0Y0rX0TlCHAQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Music'] None https://imdb-video.media-imdb.com/vi1420215833/1434659529640-260ouz-1709561756053.mp4?Expires=1712786803&Signature=LCzhcX8920q24aHDRA~QOn9yxnyZJtHuYFGTHvAAoiwLxcnTLlADyv6JNZlm1FnpZwtGDFu4DLUhCEJ6SsiyOaQrw~w9zCyvnF~kEm0ObY0hwVYxdToejlSrRJID8FS7oMBcT-YVrtbFn87RPzA56oA6i41Xa4mk7z2AcOC6kDOseYoFqNtixHOfRZ1nniMBy6JreqBz1jz1RUnvI-2mbmQiiaYmrcBFcDZkrJYo7FZ-gCcVQdvu49pLu3GYA771YEWWQFr8y94mlN7~X5JCy-3oEKW7GNV4U8paOvKQWbkFZyTbLGbtux2fvYgyxc898TMG3~4tNtlC8USwmOsjIQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi747947545/1434659529640-260ouz-1710423737675.mp4?Expires=1712786806&Signature=lg19m399iY0qeVq0N26DqWXrmWcDx~nzJFo7YKWUNjrSNwe4p107BIaTfffb2Q3OUYmoJRDvIFfbo3Y5YtVdiF7u-fH7LKr-61f5n9Uyw6IxWW8DzG7Fo3~cLP~HCuBzP~UOkUfb~Y7kj~j328rB7HxahvV8luD8sRSJvZMXWxC55cwPSrmU2eaGPzSUc4QtaFduJhVgjky55zGV64RnsrbQ8RWJ3avyJjq-ZzkAV-4tXcGHNkWc3Mx3keJDLTHvFzVtkeyWre-hOHqfslrcCOaB35TT~So5phEM8y2yEvRPoDlAEyVPSIUGoq0eDqQCfwghmKxLvyN-ka6BGaI3EA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Biography'] None https://imdb-video.media-imdb.com/vi2237646617/1434659529640-260ouz-1706796555677.mp4?Expires=1712786808&Signature=ad~Jzpg8V94sFknRDx8Ytpj1NKRe~7JaefmIaf6Sd01~5RJDlaW--phI3rc7ykuObAtjQ46bBI9Ht6oOR7-xwhq4gBZ~vhbfvAKS-8J8cleZQZ-vHfJmuv9WZCucQR4YbG~yCkIe03EQqwGjtuJXVLxjVP-t1lhvKQjZdoejJxVgnj5l4NplCF9fZuHFMGifQAnu-RMiJK1N8CtJ3vCUvyYisQib6SMLjQi2QfHwRSlJdj1rFTrOvON-OJNnwWQcQU89BFNX5Nf0RPwNi0ezTmXCiERWoZt~L-aJhYoXfaQVOUhJfGjxdzv08h175XTk-N23M8n8SFNTYPQs5J0iyA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi3986736665/1434659529640-260ouz-1709141421242.mp4?Expires=1712786809&Signature=KfLsZJ0Ipi2RsG1mVREAPvAhMliFkygxFJqi59MeY~LxCNEbotCCO6lu~TcZkmwT4uD65Iw1wPBImGflIQd23okgx9FTeVAVcPDU7Bk~7dUiumoubzTsrGByep9NW9J5QO9N~rISivdcfHkipIggpjg4zQoawDC7LTHvym1AVrfK1EvZviMetY~uXMcRX3-us29lT5CW4r1lTH34b5vrGOub3cnyp3RgIijxzEIToyxVr48Go4nAvqeVHyvKqrQ0dttlDADJUX7C1Mq6xpg2mBLiHwiFT5iE3nXVJmcnr2tqoi4Nh0pbg6nFicBKKKCt9MgDlURoEQ0JkkxW8eypAQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi2637547289/1434659607842-pgv4ql-1698775998282.mp4?Expires=1712786000&Signature=ujUV6OpsqYmJj8gVsjTioi7IWLqdtA6co4c1TUKWcfJsHQgs3F7yMDoMzxyQ7pl7SukA-gKXMuvZ40dQ6EwfcdCBLB1eRVvvBRViRk6c9mHRKcSRL7y~lJ6znebm~bUo7F3yTybJizq3SnkeFoKQSrvBNwlXRGMMgpJVkCtz3ffGgyedE6Q8aZynD-kLXhafl~kl3T009Q3rdIhI0trZ5JxaK-HRlhdiuFy6my27S1dg~MvF4EmNT1CmBaflBZPJ4nWouOC65VNSpHkkJ~Co68PMC~T5hEsUlf-Fp8tV2yyqx1qN-yni9WsC80Ukyk~KCgibP4lOKmRq-6f6t~D8xw__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi3533555225/1434659529640-260ouz-1711120296330.mp4?Expires=1712786813&Signature=EzQbJYNtCpiOFXcXXMDDKjddCzM1U8ZG~1yred98I55NnibXuiixGRiyI8Q9eB3-WSYtzlB967WsX7vqPWuYQ1go1USakBdw7-BJ0QoVmIFB1CpC-GDERcPdXPY3y36hEybhUtCaJZqCTEQ8IwmKJA8CHNyt-v5Odtszc0MHtR7XgbLg7kKtdhMriRABstNDdpNsUbP584RZpYLGgNsHSPOW~1OV0abp0EzuuXG97180oN4UJB8cbmj-91gAHui~l3lw5YxmcTsMbIJUpyD0TaQqL7xMIWLiV6o2-inSemJ7I~UiWeiCnRA7b4noFe5vqwtbWdNqiLuwjWl8jHVp~w__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Biography', 'Drama'] None https://imdb-video.media-imdb.com/vi2892085273/1434659607842-pgv4ql-1523563231489.mp4?Expires=1712786814&Signature=G6bSxKRBkaCkP2W214tKcr9tvd1FiGVSzMOayTUljkQHSHO5IxOQpwMi11XrnXSbQtc1IHAcCWkBQphTmrjflerpmj4YMFD0KBJFkNUG8dftI77rqwDZMUka~-7QPtXM-2OorkhNZeZHUgA8tTh09EogJZ2Qa1LYtfMaIhYGKCOUqa95NyQtZXmGoVuXpLpDgjtBWE0FUAPY8EBsVL8eI6imDTI3qgsXPFl-esUrw6I9ksgrqUKVGETZ4htIkET7T8J9zD~NAUzgBC4V4UWVwrDDKyfNlGaPXdVqjhBBQ22MHj5x2up3uZcJ7XeZ7oGk7mC3XQSiRjWvrSIb9DlqoA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Crime'] None https://imdb-video.media-imdb.com/vi1734330137/1434659607842-pgv4ql-1706784649826.mp4?Expires=1712786815&Signature=m3Re0YHFK3n6SC3auDYxL5-emLbPqA5zMxSAMBJJ8ULect5gcuUqDloTqQNWkr3DUYPCdLLU4a4SWof-L6R-OITqG3v~L~nMD7mYXceSIu~BsJfPGBKH4JgTAdLGHP0dwp-Jvu8pa93KhNOamI5Vit09VEiP0BQK0lda~an8Gco7fu7eIQFD0bIgXyGRHIjfwJG9sOsy5ucl8eFbYTv9Q2foJQz3rqwv3Ju9kxsati6k8Xp4XHl5qnMrgvgLDraUJabEK5KvIBkJa4o6kXf5Ya2veO0QOI2BAfNaYIw6s31L-eDzmWPkqyNghJSuEquIw0QiEbwNzHhNoq36LYlpng__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Mystery'] None None
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi2315103001/1434659607842-pgv4ql-1616198441164.mp4?Expires=1712786818&Signature=s1y1xPDsR1h--yF9Gfpf45M8Wqk5msOgX6u24pqkcgc0W7eWCXD7Zu0DuU-ocv5ZcJFI9affqcRiHj0I02xnBoVx1ZHdDTvd1OqaepACOt7K7ZI8-MGfh2gYr4tuDuYQNHl4VCHjXKtnmEMhfvjyeGkfa7xKoSqbZiFnK3L1FDToGxWJwQ-EABOTu88n1fvPsn1pEdU0lwav~yna8A0hu8xWWx6ZC2YtDakzV30Lc7SRc40KvxielSlPk9Dk6d~duaF9cnPrt5wrzwKyDKiP3NwOI7JkYMnX8hF1ZwIJ16-rRbnyRnb35-zDQyIY05xm8fb2VaWbpSYmYTfNQFwqAw__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary'] 500000 https://imdb-video.media-imdb.com/vi498124313/1434659607842-pgv4ql-1707930275932.mp4?Expires=1712786819&Signature=LLARiVJL4-mi6gZvlRLxltq~Btar9E2bKSEzTjcgbamYGmyzFemCJHtf9hFNsYhudNek~7tnvpIJFyF7FDqRu9OViwy3CJp8aocRbzlFsi9CJcm8LBoDl~p6lsIgzPXTpH4cfFmHjpCIpge3L47ESqy4u4fp~rCueDOqoHr9g5UhpbDcVAU-u1YM7Tad2NRClzFWDupfY2AHkUCFMYLWvlYwqF0ifD30DqYbU3qkaTgwA3ytmTV2i85--20hAD9PNMXIkvjWDRvkvBJtZTqfpKq1Vrp9nj7ssrd0tevtZ5IAEJZiFXcursXF1hqf9Ye3htUFOE2n7J0fFNCFefemhw__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=History&count=50
# ['Biography', 'Drama', 'History'] 100000000 https://imdb-video.media-imdb.com/vi2053751833/1434659529640-260ouz-1683541736696.mp4?Expires=1712786787&Signature=I1ARiBCPcJpwjALuLSXVBvvC03NIQLGiCpqV-DfctpQ0ZuONcof96ExfssHBGfdFrd6ZSrw0fMzLq4saHqHJ~YnhQH82y0dY9uLViiIIDF09xbZdNSpZoitSzfBgfyo~BPPRNZV2-qLir3McoxkacafkEqlvnDYI786CcjiRoAGwFDMwtGkKcVzBy-BNC68Jx2pDgz39rnBgj5T1e2xAmS3qXSuzXrvbmBINCKhjtSqUt22Xc1yJx8Y8dS7z4GyXWdd8Mg18l-YjMqsXhpJwcN6GX~YlpetQB8Y6GFZrJ~p1EaP10JST6MzHTF43Rht3pmunlcB~jTKre0aJLAmKeA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA

# %%
vidcap = cv2.VideoCapture("video_name.mp4")
success,image = vidcap.read()
count = 0
while success:
    cv2.imwrite("test/frame%d.jpg" % count, image)     # save frame as JPEG file      
    success,image = vidcap.read()
    # print('Read a new frame: ', success)
    count += 1
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
