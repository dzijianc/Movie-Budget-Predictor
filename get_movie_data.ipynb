# %%
import requests
from bs4 import BeautifulSoup
import json
import cv2
import csv
from PIL import Image

# %%
def get_genre_n_pages(genre, n=1): #default is ==1 which means 50 entries
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1", "Accept-Language": "en-US, en;q=0.5"}
    start = 'https://www.imdb.com/search/title/?title_type=feature&genres='
    mid = '&count='
    num = str(n*50)
    genre_url = start + genre + mid + num
    print(genre_url)
    response = requests.get(genre_url, headers=headers)

    if not response.ok:
        print('Status Code:', response.status_code)
        raise Exception('Failed to get web page' + genre_url)

    doc = BeautifulSoup(response.text)

    return doc

def fetch_movie_page(imdb_url):
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36"
    }
    response = requests.get(imdb_url, headers=headers)
    if response.ok:
        return BeautifulSoup(response.text, 'html.parser')
    else:
        return None
    
def get_genre(parsed_html):
    if parsed_html:
        genre_section = parsed_html.find('div', {'data-testid': 'genres'})
        if genre_section:
            genre_tags = genre_section.find_all('a')
            genres = [genre.text.strip() for genre in genre_tags]
            return genres
        else:
            return "Genres not found"
    else:
        return "Invalid HTML content"
    
def get_budget(movie_soup):
    try:
        budget_div = movie_soup.find('li', {"data-testid": "title-boxoffice-budget"})
        budget = budget_div.text.split("$")[1].split(" ")[0]
        budget = budget.replace(",", "")
        return int(budget)
    except (AttributeError, ValueError):
        return None
    
def get_trailer_link(movie_soup):
    try:
        official_trailer = movie_soup.find('a', {'aria-label': 'TrailerOfficial Trailer'})
        if official_trailer is None:
            link = movie_soup.find('script', {'type': 'application/json'})
            json_ob = json.loads(link.string)
            url = json_ob['props']['pageProps']['aboveTheFoldData']['primaryVideos']['edges'][0]['node']['playbackURLs'][0]['url']
            return url

        headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36"}
        imdb_url = 'https://www.imdb.com' + official_trailer['href'].split('?')[0]
        response = requests.get(imdb_url, headers=headers)
        page = BeautifulSoup(response.text, 'html.parser')
        link = page.find('script', {'type': 'application/json'})
        json_ob = json.loads(link.string)
        videos = json_ob["props"]["pageProps"]["videoPlaybackData"]["video"]["playbackURLs"]
        url = videos[1]['url']
        # urllib.request.urlretrieve(url, 'test.mp4')
        return url
    except (IndexError, ValueError):
        return None

# %%
genres = ['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime',
          'Documentary', 'Drama', 'Family', 'Fantasy', 'Film-Noir', 'History', 'Horror',
          'Music', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Short',
          'Sport', 'Thriller', 'War', 'Western']

# Randomize selected genres
# selected_genres = random.sample([_ for _ in range(len(genres))], 10)
selected_genres = [10, 15, 12, 1, 19, 0, 3, 9, 6, 11]
def get_training_data():
    with open('test.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        fields = ['genres', 'budget', 'link']
        writer.writerow(fields)

        # Select movies from each genre
        for i in selected_genres:
            genre = genres[i]
            doc1 = get_genre_n_pages(genre=genre, n=1)
            movie_tags = doc1.find_all('li', class_ = 'ipc-metadata-list-summary-item')

            found_movie = False
            j = 0
            while (not found_movie):
                imdb_url = 'https://www.imdb.com'
                a_tag = movie_tags[j].find('a')
                href_full = a_tag['href']
                href_part = href_full.split('?')[0]
                sample_url = imdb_url + href_part
                page = fetch_movie_page(sample_url)
                movie_genres = get_genre(page)
                movie_budget = get_budget(page)
                movie_trailer = get_trailer_link(page)
                if movie_budget != None and movie_trailer != None:
                    found_movie = True
                    writer.writerow([movie_genres, movie_budget, movie_trailer])

                    # vidcap = cv2.VideoCapture(movie_trailer)
                    # success,image = vidcap.read()
                    # count = 0
                    # while success:
                    #     cv2.imwrite("test/movie%d_frame%d.jpg" % (i, count), image)     # save frame as JPEG file      
                    #     success,image = vidcap.read()
                    #     print('Read a new frame: ', success)
                    #     count += 1
                    #     success = False
                
                j += 1
                print(movie_genres, movie_budget, movie_trailer, '\n')
    file.close()

# %%
get_training_data()
# Out:
# https://www.imdb.com/search/title/?title_type=feature&genres=Film-Noir&count=50
# ['Crime', 'Drama', 'Film-Noir'] None None
#
# ['Drama', 'Film-Noir'] 1752000 https://imdb-video.media-imdb.com/vi2388460569/1434659607842-pgv4ql-1616203164916.mp4?Expires=1713368363&Signature=NMgxmiua~SFBeW5bT0oztBDmLH1YTCUmcUEuuoqRapy3R04FXz6CHAickgWv~plN-iVmmrFOFgqVr5fRyQZ74XfScUR66zKNsBUtLEGS0wpzMETJcJwLy1cJJCdBcu-nbgYjS~y4iQEOAETXQww3tOwsF0Z04GM3OELxCEoBl7zrLCNJq3nrzlnGrVTnZPmJcRYLSm4HCjS7e48lbYC5m4wkQv9YXOAbbiRcc5fLW0L4i8f5GDR3EG~vMLuHzxwsnaX--FQWzCFXiHjZJZWiBK70ARO1gIKeHMilgvArdz1FSF0hlpDqJvxtFDDAYHAmn~9CjkHiDmPuii9wmvgt7w__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Mystery&count=50
# ['Crime', 'Mystery', 'Thriller'] None https://imdb-video.media-imdb.com/vi3881289497/1434659607842-pgv4ql-1706229226874.mp4?Expires=1713367683&Signature=qAf4YuISEbhX2B6t~yiOpuH7ASrVKcSJOWpjAhnG2dJOra01VQ3Z2uh5q47evBX3Jbry4ERN0HiOxqciLWhtp607KAWlx2gOGJtlXlk1iqc1jnP~Ho4Qcmn7E7GpGkTuUAxBGa2M9jbdRIg5u0Q~VBHLxlKR6WNbyCiGzbCsEhKNqDWqj6TOcGI~g~1bS~Yx8ns6VaT5iH1DtSWNmXy62PCtG750zyt4Bg2gmMTrA8Et6iua6jtVnyjddBjEWsu8x3p-JoqifhlGMIbsJ1JHr5~PblWqEojZZy5ZHKqGW3N0QSRNcnAzaVYC1gXYMyDAPMmLwwu63at65Yu~9Sx3mQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Crime', 'Drama', 'Mystery'] 30000000 https://imdb-video.media-imdb.com/vi672579865/1434659529640-260ouz-1608655019804.mp4?Expires=1713368367&Signature=R7XWgCKsnRTa2UMqK13oPdRtaVVs-G8EuMXAMvsiI5Gu4C01UDrUp7KLq0bbnEReE3IsZUcXWP3BcqSRuXbpZYfNVuSUqKQXw0UN0FsFt4hKceWf~qqk3HYTqPKzJljEpybvzovJrII~CQLK-waQoOZ-XOB5x1z7QiSzrkqpQ~Yw6qhZPxM07Xz9~GxUj2OQ5CNklAJh~lSBqFp0XLzGjWK3ApNYGVDclD7B4gAgJ22AY-t2ThlAABQFe5eP4VRkoFH93Lhmsn3NoroNrTI9ZmAkFSW9h3r6xxQtHsYssULknuzQ2eikEIXh3x0ut9ap3D5~6UrvnPH3fCm~CBl80A__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Horror&count=50
# ['Horror'] 30000000 https://imdb-video.media-imdb.com/vi934266393/1434659529640-260ouz-1710173661362.mp4?Expires=1713368369&Signature=QanR17N6bOg4-t3beVH1ZSckqND49tPh3PEMUoCL3lChW8m1WefWxDD5xoX7MkoD5HMkg9CPQmbozu1CPNKlyClrbb1qSkMNZXz~AyClSESH1u9Ht0Ce3F5sTc-pcIAHkLgJ~af~DYUgxDIr4bQtecYDM4bBCTKoggjx9ShOclSHfkxrPhhmhl~H5zthJkRLI~D7LhBsLPVq8aEMp4sX0FDZM3H7Zd5lESKMZkG7aAxFg3vS~2W21BQsUkJblowlHUKzCx3RZySxZeQOVTx9dKDlEO4Tej9RgyAbb1xw9fTYQU~Bk4ikbOULoCImpu4x6H80Fvppx~ZQ96pZTtzJ3w__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Adventure&count=50
# ['Action', 'Adventure', 'Drama'] 190000000 https://imdb-video.media-imdb.com/vi3137783577/1434659529640-260ouz-1702406362869.mp4?Expires=1713368372&Signature=RzvBxR-100vaN~TFkgiKNjKq5MSWkczuH3lvCCcWILpT83HluoCuc4fGJUZWjsLY~M4eC5Xtd8DCNIYUbxP1rDmT4Wt6yGM-UiZMTaFxHEwwSQ2rq3Pyz7rjGgqGaz5gLgAtI1hQwum3NVDG1tauCw3cy71lC9RN5fu07zzStt3GwgsyfWAc25kmdFRlI6tcUDUPjBamAjNOOtMgCR4D9XlmQES8xF6EMnKhtC6lngwx2WqW2qzbUPVQFv6aZBvfd0kDeIGv~uB2twjDM4LfkDpbft1jvZF3hrTJYHs9SKjw~-wiz2yNnIenFnw-n4C-S-kMIbOiPm2V7NDkmG8vVA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Sport&count=50
# ['Drama', 'Romance', 'Sport'] None https://imdb-video.media-imdb.com/vi2491663897/1434659529640-260ouz-1711548437338.mp4?Expires=1713368374&Signature=hjTRHzynazahcZ6HeCPH4m7G8N1j4NLCvIr2t9sNlT7M4SM5xbPINCcjDjY2uP8X2aDryyvlxoIvvGS9TTgGR2VQo4DZDdGFFFZlpHFUrnCTDxF6g14bqoY7-BV9qJV3UMu6coNOqSmZf87AisRwcPJ-84SI3zbj83qH~pEhc7TJka2ADVWrJaz8Uogc7xlVk0HYVLW85VUcFAykO4ihjMfQ0Oco91TDhJUdaDuvY0Jr6cErkIkXqbxO2au-4PAibT1avb~7wXten8v9xPqVfU5BXwLrWrriJzOTqGT7oSITXNcuO2nLm120f6mO04hLdmifCxLFe6hnX6OwaWb~Ag__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Biography', 'Drama', 'History'] None https://imdb-video.media-imdb.com/vi2475279897/1434659607842-pgv4ql-1712039375953.mp4?Expires=1713367949&Signature=i2AW8kxPV5Joa8eG4QRnr6rSTDsgoJX8PDHckeoRzqSOX9r9XKt1G~6-8oEU4x138axGKuprjHp5STh32CubisIQ7ijqRHSIugLfHjduQRS8Xgko5iWp1yJmsYcLdwlVa7moIihKiq5DkHyzVSFgC1WI4DFu3E8CO4s9fiuwbj5kBZuLCDBJqwzHpmyPMmF7ZyEUR-7bgSNBB5J7ygGz4x~ze8CNR4CASgI6FNl9Sta3~QY2MeCAIbyAVwOhTpv8WjEyioB9VS2tNKj9VunO1g00z2Ydhu5gPTjwQxebplBHV52fn1HMhXOWmjikfzxdkitliapqdIrFnhajWL5I5w__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Biography', 'Drama', 'Sport'] 15000000 https://imdb-video.media-imdb.com/vi2915223321/1434659529640-260ouz-1697034123918.mp4?Expires=1713368377&Signature=etrXn1xT5XTqa0Bl-LQRdLCBWDFp5vjITIfZ3o6xKmxnGFIZnVFBJlY0pLjEyvcMyH5Qd-dc~Tf~obt7Ymq3OwRoqefj72sfNVxZfnetRWNXl83rHvCv-CkSR-uXLVyzs2O9r6EzbxamqNF2IgcvW-uLeGFJ1mwjRdZlOqq670Aghk3B1L9o4CZJwmGok2XB~PWhLnp6vN9AlI8GTDGTCg2VyCyHXURfVt6RS1gnar7imJjD57k6JRpmA5s26wxjpP~18nxOhF-SVKeaBcmAAdrSbC2PFksCOPxrdJwYwpXahpjbdStNOfjo1~0KkXEp-mE3gZUo3BQE52Oy0v32BQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Action&count=50
# ['Action', 'Thriller'] 50000000 https://imdb-video.media-imdb.com/vi2164770585/1434659379400-8cjq25-1702483702006.mp4?Expires=1713368380&Signature=VYr4cig4Y6SjqnWyRHO5ahirDBUwnHzlJ5s2QVk74WSJLes~vLXS4Ow7HP5BpZpildBwSqYEqgdr50Zd3EkbZnRPpttQASJxH2fZce-R82-fGbB5liS0~wrZHqmDSonfe~Si-NnIW~FGoeYiNaojoEkq5fe8IL3Y7oVq48C79Xzfh4JpQoIturJtHcPJz-aqiAsSJ~OhGWaQ8N1FKgp62LtNv76-9vziXyqZKhPk7z13bL9n4lETlUdBV4fzHBomk7eoda4tHwEX~C80T6sE5~XniZP2E3EvgZNXOhZDBEZ3Ut2ay8kwHew8XtVzZri5L3GIPPtdHbOegRpB25iWdw__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Biography&count=50
# ['Biography', 'Drama'] None https://imdb-video.media-imdb.com/vi1972946457/1434659529640-260ouz-1710771220936.mp4?Expires=1713368384&Signature=M7enpn~zquYHxlZDqQgHNtL3T14naGUEIV6NCnF7-8lrquQV8PhuHdSONdVXBD6qR6QlNO1vDlyzR~yrN7E5bnK8pGSYIiT~Qqpr0JTNSkvgMErZcabvtj1h~ar9BuiNgaDXKjSvee-mC4OB8QZHd~zwVA9hxBQALrz2dBrxejLTO9shpgdDLMNkaTWEEv8CNXqBcFurIQICO5tFoYcS2xy7oKdpQ6OiaCrm55Yo4scvG40MfCZq1X3PePF0ykwXWDry12gDzXeh9My3lwolnCJZhtkGevyR~~TKsBU8jr8EgzKZSdsIEOQTpVbvkF~bd4Z6x-j3WucHssfoATKGHQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Biography', 'Drama', 'History'] 100000000 https://imdb-video.media-imdb.com/vi2053751833/1434659529640-260ouz-1683541736696.mp4?Expires=1713368386&Signature=NRbcYlC9KN734vpGiNI6MJRxkURj0f3iQd5jgncXLdvernnVfMl1mW6vsNKrX7-A8--DwbXo6e2zDUxpkmCJYK4VKKcnp~aIuR0Ok72OMmY-KCB56tZ1nmmiSFxFXQ4dxNN1uhrWLRwdqJ3-DNOMhCp3aXIywaD4fW2I0NK75nrf9F6f8Wcwxm~eCfOKBrh4VG9hmiEWxtrGji8L7GRUkwE4hZTqmLDZf1V8eMajPerkTT1~PJZGjBwhAPAH6c9RRZ9533Oj47U15KkFmrurPZf0x0ckfIcsVCAgMCFQTf5VPvwdsBtrQyP6C6oq63EAhZm4h4U07HgfVCtTd9KFYg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Fantasy&count=50
# ['Animation', 'Adventure', 'Comedy'] 200000000 https://imdb-video.media-imdb.com/vi2144782105/1434659529640-260ouz-1695831330439.mp4?Expires=1713368388&Signature=ClYq0F0152l6SMqdd7N0te8i~K~a2ANesSHJQzd81f~W5lXnIThwg16JXzbbZJdohXhXKGxD1JA~x4kzfqqIimGEEGUXHDQdjMqgjJO1k0DM0OQExu9GejXJFjmdzX38mfGGIzs4yhEB-1MrTMBQPvU0RYEd~0gxcPPSdX69wQBDuue0i6SP4-LNYwok9WdqVmSV17ct4fptslCvoXzRVXEeiwjB6E5MgsA2I6xYDaAEUDI2fcVnobSXWpYsAv1yg1reAk~89ezU49Kxk8JUJ1dq51MwZGgmm-Kmk1fe2qLtil~ziAqkn59QUkakUT9kXxda1egum-sVIiqMNBg6ZA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=Documentary&count=50
# ['Documentary', 'Crime'] None https://imdb-video.media-imdb.com/vi1492239897/1434659529640-260ouz-1712679832293.mp4?Expires=1713368391&Signature=EYW2Tu5X8mFdcic72xYe3MF57mcINzH9eFLHOU~~J5aGN~~0wn8c4Rlqdx4W4fttRIlq8beBRrC1cH5vw41dJvtUYZtPET6rnESHGfSUDiOoyzRCs-F~iSHpGRDf7lPw38ePDNGeIS0j~c4nbl-ny8hjDrq8LRBlaTocU3zMqK-Mo9UVGC6hzPBOYOBA~4sHb6Bp0PzR1ycin1crClJgIMZrfqc2R2IFqCGkLGT6CrUm-yTdNHT8xuv2zklPctbu9OshzAkIzMYryRDC30DFkC55scRPmZg2NMuGzI5RDJy1VEz2Qd4BbohvfJgdnskDc3gS4uRPDzdNGPO7oA7Yhw__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi3533555225/1434659529640-260ouz-1711120296330.mp4?Expires=1713368393&Signature=RKE0mAXzuBCY40~3VA0Yy9s3uwX3p-m3HsiRk8V9hDPDaZXqxZQoeChLexVDt7jObmZB86aE92xSVhFqyV1pEqFlimzO9FlzdacYUsVXArQ1UoWVWPsU010nfEtAZZJlY5bX05x1oy71cOxtjEbQLweJrFuLPESHgUa8HbSThBDiQrMU7KCaFpDt0b~SC18mQUgRmxHceht3V7FDEBwxbVKwUq0Abk-K7L8Z-4Q-a5bc0ZslwTugz5fNtfTNYJv5JJ5IHikUJ1JiamYEKDp~q-iS8~5dKncxrIrixnh~~pG3ahs6NPAEpP60M6smf1dc6VIoyLFVXzJUbNaqVXNJzw__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Biography', 'Crime'] None https://imdb-video.media-imdb.com/vi3901735705/1434659607842-pgv4ql-1635462633455.mp4?Expires=1713368394&Signature=f3hPuAbuct-sXqXF7vDKVWsinjAD9hKpvOm33hjzQhTpHd8rgx6O4BbRyDaowZy978mtN9Er084WiaXsc0RpGRgs6eyNTPCGhgrTaIBFWvMsq51GkK1e4ciQ6IB9oLxawHDFw9N-6OaXhhTUzfMxDPQUSo88m-p~NOLv0kPNK-EW1lOefkEJityTuqdzhQLviuNlcfQvu4Rd-SNZ0W7Ie2lE2zD7prHNuWFBSGAT7lQMQtbBg4TaVj0PXKE5z9tael28eNd2wWl62YuCQETwE0r-dB0S4XGTs3wx35jK~fAHbfIUKK-Uy9e6NsLTmE4N-Rt9KjjD6pi~TMJK3Nto7g__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi75875865/1434659379400-8cjq25-1711664369425.mp4?Expires=1713368396&Signature=aSspsBHjoknyEyf1mXwsL0mAUMKs-6g2wPp1xlsl8jvf1Mx~sc7jjlZBxY0cNVjYfucKgccsnnX0ZO~wRTUyFo~x6AUAU2rLVPao6Fk2AEF7jK0ajKEaVHVU6NP0THG0PTkG4uMwf79QiAscqMcZAHbBcp83MXH1whgnuU0OxFsmqCt6puqK0W34hob-DHgEXoFe8Bqvjrwx25ar0cAqSz2noWEL-ux2kITbU~AsLf2l7z1v1AFZR8PMJ1TUh2gJJaCS7x58498jQW5khP6WlotQL8Qsp2Gjj5OXZpiWC-h08P4Bom023nmbZvymm5EN2SxR8xvDH-ROpVh~qv3LQQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Biography', 'Drama'] None https://imdb-video.media-imdb.com/vi2892085273/1434659607842-pgv4ql-1523563231489.mp4?Expires=1713368002&Signature=cx~tfjOBXF7dZh-XprE-It3~-OLb1UlzoWM~hQ06DgJ3twW1MtX5CTug-iLmNLFmKtzVnNahmLU2cy6aIAS2rGNJFQGx5nebbBfJBSpYLXLrN7YDuegVJJ4vKrH2o1F2GrvowwXuJhGhLOnyZuAtUIun33Dt64Nu1LRK5g~6aui9Dl8~e~z1zwLPJ-UkgEe4NeVq1m3rbTfU2OWWXkY9tqQWsb0QlqHmlssqlwWbFj2A3shkI3tT5sUJjHuA-3d6UeEOOIO5YkFTsDdEjHACrzNYLNfGkGyTyUoR9mTv9ZAblthavV862LjRx0WKJZGxeJzA25WE3R-JmemTAzbuaQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi747947545/1434659529640-260ouz-1710423737675.mp4?Expires=1713368399&Signature=lj2yV93E45mVPl0lb24~2wB-8CXB1Fy5x5CtDGn7SISJdGEaOjsjovJ2h0CIj1v0sP6jKjU~MSc-G8r261bzRkkYjqGhwo1hW8J2O2vxLJWggzlF8qhYUJv5D0oHETXSGJ9~ef8gPJoCPQoSBoESo5HcHkneZ3~wHH4FBPokgo3xaRjqQT7-6kdaFx3w0uroimspBHjBOZqkJTLO8TFhUInQ-X8JdO2Ej8TftVgKXRQ-foZNJBuZZ3GzIflV41PvdyrxunZriBpEi2Gbu5Jyr1BCXCnQKkaoYAUvLNlXiHfJmDKUYB2v2btZ~cNrpeLqe4DcbsM5VQuGUfKSmniRlQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Music'] None https://imdb-video.media-imdb.com/vi1420215833/1434659529640-260ouz-1709561756053.mp4?Expires=1713368401&Signature=p7ldVguBaslWqkQHFW-qtEeLdUNyiiEEp6vPlKl9w6vbPNLQhuZLon1SH~9WUuICPI7SFqf8qerbXFJC-QDDb9VMUss4lpk9nyDcBYjXYHyw6gzPt0Lp~iPZ-mEj0faG9p5U9Mhohrl6RCzeCdES1plJtob6ImIBWVxnEi6-FTPkZ3wFBWov1QSSBLBwPuFWEDaXyYe9B95oawXyhiFBggQqsTRwh9sV-8QI2qeF-wbEjjUzElV2t62dpKkwuj8H7zQE-HsID51TM8jCCikM2ha9PR-9bQjIuGAvetHmcsiHGnfFRRYfIq4XNe9jqTtBD3faMtpQf5s9cIsxKnlCsg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'War'] None https://imdb-video.media-imdb.com/vi336774937/1434659529640-260ouz-1700736399325.mp4?Expires=1713368403&Signature=OPY2r3HYiLODBB-N5HIr0tfXf847MsYz~wpo4VaQsLJsnUkwrbI5NI5n7E37-TR0JOLxFjyWhG72osUnfY93p0BQrSdIeTRyKoevUvLXs5T9V4VmbC2Fi-D9MInV9r8Xig0v86cKLbDgd-dX5s78l5pyj5RiBtZxwR-jksr6L5Y6z2CLTf~SMQMsBdE3a2qOx7PBuhuhsLuWnaij8cle9QjWiXzebjDC4aimOYDfi3SDbMAy6PB-zMbIzBG05lviZi9NSpZRKOu3utlr-XM-9GvfmPjsOHFXVpCv5LgvPymHcpmJOmlZTyLJ~8Gnusgwuev4euMAFH~MB-nQ~jvU5A__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Crime'] None https://imdb-video.media-imdb.com/vi3717383705/1434659529640-260ouz-1710341817819.mp4?Expires=1713368404&Signature=t-zh4gmh~cl1pHI8Oo3Rc2MpxvtYNUdlzAl34xHh5C~lqH~RCgQP3-Nd5k6tDrXbHuFYMqhOl481wMA4R140P4KKh6B~gWIXGxnWW8C6MkHPjQYUuPTSexepzPmmNGPSvNsXgozL5W2Ms3cDqUENbFaHSguu8wVUpXRpLZ1Tw2PSj-2QJjLDaMBGyUsEcQWNSVrN9~TpPad7oKypBeDEmeklqcc1n1NU~AVUA0R~I5voXhDH3pew50bfiQ~0qW~Tul9d0njygkSxl3KBwpzegCiZNUfmSv1eqNspAd~BRT2CP6WscA0XVbKZG-oSJI1dCGetB1C3j~QzWCMxmzZ4rw__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Biography', 'Music'] None https://imdb-video.media-imdb.com/vi3689328665/1401497881123-xszl4z-1432102161428.mp4?Expires=1713368406&Signature=V2dqxsqgZ27mfxv2j0-CWYdE4J22-SqL0RUHwqIgUKr8Zd0lEVBtPGcudN27yWYAZkBJnfElOPAdsPYV1RKUK5GbM6EDKEGE7fg84w1A9q9r5741yFu6xNx20k96mCwGT3CvBszqvldmRfjVNulQRlt3Txlw4d5m~GnaeLDqJuxaYJubPPwItpoHX~OgjH5hsBbhVqYxtzrTFuXaWhc2ucNYLTCAslawMCGp~MhT~GG~yewNpvapoqgNSDSkROUj6BK5XtSd-aQPOodfX2ZLKxT7pIHYh~7IzLj4ig~-HLeW5WhA53PQSi3Hv5v6QZHZzgb9OhuRn67paSQohSRrXg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Music'] None https://imdb-video.media-imdb.com/vi1268237849/1434659607842-pgv4ql-1710635104214.mp4?Expires=1713368407&Signature=VBZEoyAY5ByVmlVJipsyuCuxAxnu0yM471rmOkJWLHcb2GC2RxVarygVKd03bbKIL2xUr65OwyaL4WqQfP02-rR-GB-hr-ecJmpxqGtKjrmLrWDEDesjfAADJKHtYH2~zxBWUG-vrGxi8pVjBgWpokenxP68NwCTMeQIxXzKmdE8jfA48QSYlhgG9vAZDReV2390QCCZdIuREcvgAgUiepiHwAHH426H2hRP8l1-f4isqOBMuS-cXwirHsx4HwdIxKZE2BlS1USY5NwvjpsdxDoBM1KSv4-J39LvN~gCrs275B0zuWBf2IbN-Nr7bepdZlyPUorYYuvaNAcWkHmv1w__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Horror'] 100 None
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi2637547289/1434659607842-pgv4ql-1698775998282.mp4?Expires=1713368409&Signature=vLeuyDy01AgFE3mFvgjE9lJ3qQmsCtO9MG0DNFirokxnLr2fcwR2A2ReN2tBBhfYaPSPqc3biBEs679zwdjzsd6Eb4GOfCDO6Xr0HRjzSWLtvGEggeAx-YPkxPf2oC34YN6gqO97EDzNiF49nQgCC4Atbu4rkpjmyyYx2gMks~MwFyoUspvOmJ-d0RA5DhVPdrzC34YCmjfWZKvbjaHQ5rqacwoZPWiS1Oxgi9rOfJWcbONxasqeUo3Ax~jffyI56Ob~q-NivWwBfQSPX83EcNe6xyERq533NlrgCokA8LNMfK1fvaOOQqb3c3NoLxvfR5-9aSiPrSIHySl6ZbFbww__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Horror'] None None
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi3986736665/1434659529640-260ouz-1709141421242.mp4?Expires=1713368412&Signature=DU88xo0ERqn7-oKxFfcV8hxldFASMcEu0ZdnNQRjzvOvU07h2ML0IY-RakzE4b1NSkXlt1a4EZZz5HvrInJY9n5KU4ZKlfQkNX9BWc2FbKzyRkBCUG3IJCia9w4SuBmfoawvSzGl53TjVkZzqhqyEMeplFF6sr2w~fxQiaA516DZxdW2l9AYBN0nfdIi1pXLMb~-JOGTZbO2MQ2v3TMBBWPNFqsD4zRv7nT5EpoqbVOynmtap86thECe~Hjteiy9cubIrfL6dA0-MkCWYoIBRBDEcHM3nnSwcNCHkLZNn8rRPQf3Tg~QGoQyh5o~hH7dcxLfW5YqeaVuvbKleL8SAg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Crime', 'Drama'] None None
#
# ['Documentary', 'Comedy'] None None
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi2292368921/1434659529640-260ouz-1709239105375.mp4?Expires=1713368417&Signature=HrzFj-Wes00h9RUXOJg0DkqWjKifhjFKZW1gWHtrYAYHdJro2q47r3-2a9sAAdtGFB5YcrPmNGaf2f-4XIOVbuAvnhRlhPcUnYMo9GFzoBwU1gfTVH636H3bxgk60W7ap137PJOTXDOiIklxCjUYqA1B14aWRRGjQ77gcnR~fxxgj0GA9I0CJ2UYFyAfKdT4pfQ0B-rNrzHl4c9tXXLNwTtKVYIH4XQCyb9AvzjirFKydE3EVOGb5eEtlzMZx~CU-KYfbXKQbax4nFcMq8nH1DXy-td9kB~Ox2~7y6tOgHjDK45a1RjnjDkASzqMC6qMyHKA0iQa8T0hsT7FgVDRrw__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary', 'Horror'] None None
#
# ['Documentary', 'Crime'] None https://imdb-video.media-imdb.com/vi1734330137/1434659607842-pgv4ql-1706784649826.mp4?Expires=1713368420&Signature=Yr~563IF5g6Z7PbTlmv~bqjQS3knWyKlvtIkHC9PB03Y6xU-sX8DeD2t4j6Pa8cXlswmuwy2-le-RDen7DlwvJ~v9YS5IQSMTaPga7PL3C45p~WI-0ewRQP~Bf7UpW94QiVYrfqWt8sfOSWBl4g~5jn3TQkQyVDfzvuykNOri5kZy69-5CANIxtE~0bimTsnjqimSR7bwg78yKm9Lp9jDO4cg2CsBt31YZS8DyZCh3tyfZyIzhwj9Ox89IJDWKDcnRL1DTQg0Lx4SaZ1NQzcBBJ5fD5~qJ4JPFwU6xl09wHQGowxRjQ2-WHj1Hmhe4LgJi2vtxAWiubH-BAcZOo1Kg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi3990013721/1434659607842-pgv4ql-1695488632767.mp4?Expires=1713368421&Signature=JlKwF4deJKcZ6yShyieDvGC76Dgy~veFyRTUx6UZZWOGzgoD0-igIgf7Nf7J2brKxD7QfsnJ3xNTklvfiV4FMw7S4owHydVy~WBBRSIH~Ke8aqrn-DHW41f2tWM~nQFa3q~UBIX373E20fG6EnDMsb1solX-lUvCyJfO-YLDhWnBX4IjfxRmujWRe-OAdyYKzhmM26l-asnjVfyc0QYMduQC-O-Kmh-2dbaqr7fQbd4UWq~8UztisWyS~F3F3IeReHNHCiPAZ7gAZeHlO75bDGwX03Z45A1C-7OeVeMQJSAct1~coS~IXz7ceBDLvX~bfgcGqQrdP4KTMGpY4Uhc6Q__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary'] None https://imdb-video.media-imdb.com/vi2315103001/1434659607842-pgv4ql-1616198441164.mp4?Expires=1713368368&Signature=vEweCIr5qxXq7xPwTW9wDm6w~ml~BB0OzufHFNCZ-1JkPBgtVMbhwbpmfhYsiRLopg2AAc4-aTRJIi3srWRGZhngd7WDgqGcIgTC2HEC9O4BcsW66AVmcN0c21LCJllVItR4X3xdWRDSYGS8SUVb8w91wB0qSJVNuIeTGzLxhJBHI2lgmQxr0gnMeGdsKp6lVafLhGH0je00lZ4UjvVDxl0aCI2vIU4yZ7J1ov3iu-jBQ4R6mtKNukgO5ZSOXmr1XaYdsGlzO~W0zL-cNi7XhE2c3nsBi5pgLAc775IHHIY3SAQNE5IpQoHZvRnDME2W2rToz-6rux0vu6IuyVKNFA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# ['Documentary'] None None
#
# ['Documentary', 'Crime'] 2000000 https://imdb-video.media-imdb.com/vi751502873/1434659607842-pgv4ql-1616204176537.mp4?Expires=1713368425&Signature=cB2tmBqIRvkDdP3kkDkU4h975Ke6TZrmOWHi95aI1e~2Ul5CRuXtNOJCubvS9DGjGNCmVK1xYacU~2v2Sj741DHxlKNRcvNZ-tFWVccLEcdCT7vUSO7HxBaIfcMEX5K460n3bViUQAQ9397xBYAljXObNHyhJOqV0syrrZnJM4XjW0HDUjrbeJHAN4O2jWZkccGHLz9oPZYRtWts-cSoJizyR3Gk8-tCxKUWS3S8kfu~6zOaJzVE8~LI-u3bEyqL-GjY7-aRli5b3cMgGMhCvGqhCLrm9MaaKdcfUDpHF-827cMiU0pEL0LTlb9ure9rlrz6M47e723TgS8MehDvcg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
#
# https://www.imdb.com/search/title/?title_type=feature&genres=History&count=50
# ['Biography', 'Drama', 'History'] 100000000 https://imdb-video.media-imdb.com/vi2053751833/1434659529640-260ouz-1683541736696.mp4?Expires=1713368386&Signature=NRbcYlC9KN734vpGiNI6MJRxkURj0f3iQd5jgncXLdvernnVfMl1mW6vsNKrX7-A8--DwbXo6e2zDUxpkmCJYK4VKKcnp~aIuR0Ok72OMmY-KCB56tZ1nmmiSFxFXQ4dxNN1uhrWLRwdqJ3-DNOMhCp3aXIywaD4fW2I0NK75nrf9F6f8Wcwxm~eCfOKBrh4VG9hmiEWxtrGji8L7GRUkwE4hZTqmLDZf1V8eMajPerkTT1~PJZGjBwhAPAH6c9RRZ9533Oj47U15KkFmrurPZf0x0ckfIcsVCAgMCFQTf5VPvwdsBtrQyP6C6oq63EAhZm4h4U07HgfVCtTd9KFYg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA
